# %% [markdown]
# ---
# # 🔵 GAN Type 1 — Vanilla GAN (MLP-based)
# Standard GAN using fully connected layers only. No class conditioning — purely unsupervised generation.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import os

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
latent_dim = 100
batch_size = 128        # larger batch → better GPU utilisation on T4
lr = 0.0002
epochs = 300
checkpoint_dir = "/content/checkpoints/vanilla_gan"
image_dir      = "/content/images/vanilla_gan"
os.makedirs(checkpoint_dir, exist_ok=True)
os.makedirs(image_dir, exist_ok=True)

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

dataset = torchvision.datasets.FashionMNIST(
    root="./data",
    train=True,
    transform=transform,
    download=True
)

dataloader = DataLoader(
    dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=2,      # T4 Colab has 2 CPU cores available
    pin_memory=True     # faster CPU→GPU transfers
)
# Out:
# 100%|██████████| 26.4M/26.4M [00:03<00:00, 8.80MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 140kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 2.55MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 13.7MB/s]

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(latent_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, 1024),
            nn.ReLU(),
            nn.Linear(1024, 784),
            nn.Tanh()
        )

    def forward(self, z):
        return self.model(z)

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(784, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# %%
G = Generator().to(device)
D = Discriminator().to(device)

# %%
criterion = nn.BCELoss()

optimizer_G = optim.Adam(G.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_D = optim.Adam(D.parameters(), lr=lr, betas=(0.5, 0.999))

# %%
for epoch in range(1, epochs + 1):
    G.train()
    D.train()
    for i, (real_imgs, _) in enumerate(dataloader):

        real_imgs = real_imgs.view(-1, 784).to(device, non_blocking=True)
        batch_size_curr = real_imgs.size(0)

        real_labels = torch.ones(batch_size_curr, 1, device=device)
        fake_labels = torch.zeros(batch_size_curr, 1, device=device)

        # =======================
        # Train Discriminator
        # =======================
        outputs = D(real_imgs)
        loss_real = criterion(outputs, real_labels)

        z = torch.randn(batch_size_curr, latent_dim, device=device)
        fake_imgs = G(z)
        outputs = D(fake_imgs.detach())
        loss_fake = criterion(outputs, fake_labels)

        loss_D = loss_real + loss_fake

        optimizer_D.zero_grad()
        loss_D.backward()
        optimizer_D.step()

        # =======================
        # Train Generator
        # =======================
        z = torch.randn(batch_size_curr, latent_dim, device=device)
        fake_imgs = G(z)
        outputs = D(fake_imgs)

        loss_G = criterion(outputs, real_labels)

        optimizer_G.zero_grad()
        loss_G.backward()
        optimizer_G.step()

    print(f"Epoch [{epoch}/{epochs}]  Loss D: {loss_D.item():.4f},  Loss G: {loss_G.item():.4f}")

    # ── Save checkpoint + images every 10 epochs ────────────────────────
    if epoch % 20 == 0:
        # Checkpoint
        ckpt_path = os.path.join(checkpoint_dir, f"epoch_{epoch:03d}.pt")
        torch.save({
            "epoch": epoch,
            "generator_state_dict": G.state_dict(),
            "discriminator_state_dict": D.state_dict(),
            "optimizer_G_state_dict": optimizer_G.state_dict(),
            "optimizer_D_state_dict": optimizer_D.state_dict(),
            "loss_G": loss_G.item(),
            "loss_D": loss_D.item(),
        }, ckpt_path)
        print(f"  ✅ Checkpoint saved → {ckpt_path}")

        # Generated image grid
        G.eval()
        with torch.no_grad():
            z_fixed = torch.randn(16, latent_dim, device=device)
            sample_imgs = G(z_fixed).view(-1, 1, 28, 28).cpu()
        G.train()

        fig, axes = plt.subplots(4, 4, figsize=(6, 6))
        for idx, ax in enumerate(axes.flat):
            ax.imshow(sample_imgs[idx][0], cmap='gray')
            ax.axis('off')
        plt.suptitle(f"Vanilla GAN — Epoch {epoch}")
        plt.tight_layout()
        img_path = os.path.join(image_dir, f"epoch_{epoch:03d}.png")
        plt.savefig(img_path, dpi=80, bbox_inches='tight')
        plt.close()
        print(f"  🖼️  Image saved   → {img_path}")
# Out:
# Epoch [1/300]  Loss D: 0.6620,  Loss G: 4.1449
# Epoch [2/300]  Loss D: 0.4779,  Loss G: 3.3015
# Epoch [3/300]  Loss D: 0.2614,  Loss G: 3.6449
# Epoch [4/300]  Loss D: 0.3777,  Loss G: 2.6399
# Epoch [5/300]  Loss D: 0.6011,  Loss G: 4.2743
# Epoch [6/300]  Loss D: 0.5644,  Loss G: 2.8929
# Epoch [7/300]  Loss D: 0.5625,  Loss G: 2.9172
# Epoch [8/300]  Loss D: 0.8795,  Loss G: 1.1815
# Epoch [9/300]  Loss D: 0.9797,  Loss G: 1.4753
# Epoch [10/300]  Loss D: 1.0208,  Loss G: 2.1763
# Epoch [11/300]  Loss D: 0.9702,  Loss G: 1.4247
# Epoch [12/300]  Loss D: 1.2002,  Loss G: 0.9201
# Epoch [13/300]  Loss D: 1.1145,  Loss G: 1.1454
# Epoch [14/300]  Loss D: 1.1780,  Loss G: 0.9021
# Epoch [15/300]  Loss D: 1.1196,  Loss G: 1.3907
# Epoch [16/300]  Loss D: 1.1258,  Loss G: 1.3253
# Epoch [17/300]  Loss D: 1.2079,  Loss G: 1.0974
# Epoch [18/300]  Loss D: 1.2516,  Loss G: 1.0175
# Epoch [19/300]  Loss D: 1.3148,  Loss G: 0.7661
# Epoch [20/300]  Loss D: 1.2299,  Loss G: 1.1618
#   ✅ Checkpoint saved → /content/checkpoints/vanilla_gan/epoch_020.pt
#   🖼️  Image saved   → /content/images/vanilla_gan/epoch_020.png
# Epoch [21/300]  Loss D: 1.1311,  Loss G: 0.9653
# Epoch [22/300]  Loss D: 1.2870,  Loss G: 0.9769
# Epoch [23/300]  Loss D: 1.2546,  Loss G: 0.8621
# Epoch [24/300]  Loss D: 1.3559,  Loss G: 0.9397
# Epoch [25/300]  Loss D: 1.3290,  Loss G: 0.8947
# Epoch [26/300]  Loss D: 1.2381,  Loss G: 0.8764
# Epoch [27/300]  Loss D: 1.3097,  Loss G: 0.8514
# Epoch [28/300]  Loss D: 1.3108,  Loss G: 0.8607
# Epoch [29/300]  Loss D: 1.3072,  Loss G: 0.8837
# Epoch [30/300]  Loss D: 1.3958,  Loss G: 0.7926
# Epoch [31/300]  Loss D: 1.3329,  Loss G: 0.8116
# Epoch [32/300]  Loss D: 1.4141,  Loss G: 0.7505
# Epoch [33/300]  Loss D: 1.4354,  Loss G: 0.7249
# Epoch [34/300]  Loss D: 1.3467,  Loss G: 0.8339
# Epoch [35/300]  Loss D: 1.3197,  Loss G: 0.8278
# Epoch [36/300]  Loss D: 1.3532,  Loss G: 0.8131
# Epoch [37/300]  Loss D: 1.3560,  Loss G: 0.8225
# Epoch [38/300]  Loss D: 1.3476,  Loss G: 0.7556
# Epoch [39/300]  Loss D: 1.3664,  Loss G: 0.7582
# Epoch [40/300]  Loss D: 1.3995,  Loss G: 0.7777
#   ✅ Checkpoint saved → /content/checkpoints/vanilla_gan/epoch_040.pt
#   🖼️  Image saved   → /content/images/vanilla_gan/epoch_040.png
# Epoch [41/300]  Loss D: 1.3615,  Loss G: 0.7346
# Epoch [42/300]  Loss D: 1.3682,  Loss G: 0.7412
# Epoch [43/300]  Loss D: 1.5122,  Loss G: 0.7414
# Epoch [44/300]  Loss D: 1.3281,  Loss G: 0.7469
# Epoch [45/300]  Loss D: 1.3519,  Loss G: 0.7515
# Epoch [46/300]  Loss D: 1.3591,  Loss G: 0.7653
# Epoch [47/300]  Loss D: 1.3724,  Loss G: 0.7179
# Epoch [48/300]  Loss D: 1.3744,  Loss G: 0.7265
# Epoch [49/300]  Loss D: 1.4025,  Loss G: 0.7452
# Epoch [50/300]  Loss D: 1.3812,  Loss G: 0.7466
# Epoch [51/300]  Loss D: 1.3998,  Loss G: 0.7306
# Epoch [52/300]  Loss D: 1.3927,  Loss G: 0.7076
# Epoch [53/300]  Loss D: 1.3879,  Loss G: 0.7299
# Epoch [54/300]  Loss D: 1.3804,  Loss G: 0.7474
# Epoch [55/300]  Loss D: 1.3814,  Loss G: 0.7567
# Epoch [56/300]  Loss D: 1.3118,  Loss G: 0.8257
# Epoch [57/300]  Loss D: 1.3870,  Loss G: 0.7773
# Epoch [58/300]  Loss D: 1.3853,  Loss G: 0.7426
# Epoch [59/300]  Loss D: 1.4001,  Loss G: 0.7493
# Epoch [60/300]  Loss D: 1.3598,  Loss G: 0.7733
#   ✅ Checkpoint saved → /content/checkpoints/vanilla_gan/epoch_060.pt
#   🖼️  Image saved   → /content/images/vanilla_gan/epoch_060.png
# Epoch [61/300]  Loss D: 1.3872,  Loss G: 0.7601
# Epoch [62/300]  Loss D: 1.3460,  Loss G: 0.7161
# Epoch [63/300]  Loss D: 1.3787,  Loss G: 0.7771
# Epoch [64/300]  Loss D: 1.3638,  Loss G: 0.7212
# Epoch [65/300]  Loss D: 1.3708,  Loss G: 0.7435
# Epoch [66/300]  Loss D: 1.4453,  Loss G: 0.7960
# Epoch [67/300]  Loss D: 1.3358,  Loss G: 0.7569
# Epoch [68/300]  Loss D: 1.3967,  Loss G: 0.7362
# Epoch [69/300]  Loss D: 1.3911,  Loss G: 0.7136
# Epoch [70/300]  Loss D: 1.3852,  Loss G: 0.7548
# Epoch [71/300]  Loss D: 1.3683,  Loss G: 0.7929
# Epoch [72/300]  Loss D: 1.3645,  Loss G: 0.7277
# Epoch [73/300]  Loss D: 1.3870,  Loss G: 0.7427
# Epoch [74/300]  Loss D: 1.3942,  Loss G: 0.7153
# Epoch [75/300]  Loss D: 1.3957,  Loss G: 0.7354
# Epoch [76/300]  Loss D: 1.3795,  Loss G: 0.7807
# Epoch [77/300]  Loss D: 1.3977,  Loss G: 0.7334
# Epoch [78/300]  Loss D: 1.4066,  Loss G: 0.7215
# Epoch [79/300]  Loss D: 1.3290,  Loss G: 0.7330
# Epoch [80/300]  Loss D: 1.3922,  Loss G: 0.7122
#   ✅ Checkpoint saved → /content/checkpoints/vanilla_gan/epoch_080.pt
#   🖼️  Image saved   → /content/images/vanilla_gan/epoch_080.png
# Epoch [81/300]  Loss D: 1.3981,  Loss G: 0.7254
# Epoch [82/300]  Loss D: 1.3723,  Loss G: 0.7485
# Epoch [83/300]  Loss D: 1.3513,  Loss G: 0.7909
# Epoch [84/300]  Loss D: 1.3617,  Loss G: 0.7602
# Epoch [85/300]  Loss D: 1.4047,  Loss G: 0.6860
# Epoch [86/300]  Loss D: 1.3617,  Loss G: 0.7453
# Epoch [87/300]  Loss D: 1.3532,  Loss G: 0.7168
# Epoch [88/300]  Loss D: 1.3650,  Loss G: 0.7335
# Epoch [89/300]  Loss D: 1.3818,  Loss G: 0.7078
# Epoch [90/300]  Loss D: 1.3826,  Loss G: 0.7416
# Epoch [91/300]  Loss D: 1.3917,  Loss G: 0.7122
# Epoch [92/300]  Loss D: 1.3421,  Loss G: 0.7626
# Epoch [93/300]  Loss D: 1.3973,  Loss G: 0.7228
# Epoch [94/300]  Loss D: 1.3748,  Loss G: 0.7119
# Epoch [95/300]  Loss D: 1.3567,  Loss G: 0.7116
# Epoch [96/300]  Loss D: 1.3532,  Loss G: 0.7323
# Epoch [97/300]  Loss D: 1.3722,  Loss G: 0.6946
# Epoch [98/300]  Loss D: 1.3711,  Loss G: 0.7272
# Epoch [99/300]  Loss D: 1.3619,  Loss G: 0.7244
# Epoch [100/300]  Loss D: 1.3750,  Loss G: 0.7511
#   ✅ Checkpoint saved → /content/checkpoints/vanilla_gan/epoch_100.pt
#   🖼️  Image saved   → /content/images/vanilla_gan/epoch_100.png
# Epoch [101/300]  Loss D: 1.3588,  Loss G: 0.7546
# Epoch [102/300]  Loss D: 1.3468,  Loss G: 0.7216
# Epoch [103/300]  Loss D: 1.3667,  Loss G: 0.7423
# Epoch [104/300]  Loss D: 1.3828,  Loss G: 0.7224
# Epoch [105/300]  Loss D: 1.4015,  Loss G: 0.7236
# Epoch [106/300]  Loss D: 1.3986,  Loss G: 0.6909
# Epoch [107/300]  Loss D: 1.3578,  Loss G: 0.6948
# Epoch [108/300]  Loss D: 1.3944,  Loss G: 0.7340
# Epoch [109/300]  Loss D: 1.3781,  Loss G: 0.7124
# Epoch [110/300]  Loss D: 1.3530,  Loss G: 0.7609
# Epoch [111/300]  Loss D: 1.3973,  Loss G: 0.7227
# Epoch [112/300]  Loss D: 1.3563,  Loss G: 0.7230
# Epoch [113/300]  Loss D: 1.4058,  Loss G: 0.7299
# Epoch [114/300]  Loss D: 1.3583,  Loss G: 0.7445
# Epoch [115/300]  Loss D: 1.3811,  Loss G: 0.6948
# Epoch [116/300]  Loss D: 1.4216,  Loss G: 0.7104
# Epoch [117/300]  Loss D: 1.3761,  Loss G: 0.7222
# Epoch [118/300]  Loss D: 1.3614,  Loss G: 0.7416
# Epoch [119/300]  Loss D: 1.3619,  Loss G: 0.7239
# Epoch [120/300]  Loss D: 1.3631,  Loss G: 0.7513
#   ✅ Checkpoint saved → /content/checkpoints/vanilla_gan/epoch_120.pt
#   🖼️  Image saved   → /content/images/vanilla_gan/epoch_120.png
# Epoch [121/300]  Loss D: 1.3929,  Loss G: 0.7137
# Epoch [122/300]  Loss D: 1.3786,  Loss G: 0.7111
# Epoch [123/300]  Loss D: 1.3463,  Loss G: 0.7071
# Epoch [124/300]  Loss D: 1.3877,  Loss G: 0.7284
# Epoch [125/300]  Loss D: 1.3735,  Loss G: 0.7493
# Epoch [126/300]  Loss D: 1.3725,  Loss G: 0.7226
# Epoch [127/300]  Loss D: 1.3779,  Loss G: 0.7490
# Epoch [128/300]  Loss D: 1.3406,  Loss G: 0.7401
# Epoch [129/300]  Loss D: 1.3871,  Loss G: 0.7375
# Epoch [130/300]  Loss D: 1.3532,  Loss G: 0.7514
# Epoch [131/300]  Loss D: 1.3351,  Loss G: 0.7389
# Epoch [132/300]  Loss D: 1.3732,  Loss G: 0.7084
# Epoch [133/300]  Loss D: 1.4000,  Loss G: 0.7450
# Epoch [134/300]  Loss D: 1.3705,  Loss G: 0.7323
# Epoch [135/300]  Loss D: 1.3725,  Loss G: 0.7208
# Epoch [136/300]  Loss D: 1.3730,  Loss G: 0.7002
# Epoch [137/300]  Loss D: 1.3897,  Loss G: 0.6771
# Epoch [138/300]  Loss D: 1.3533,  Loss G: 0.7257
# Epoch [139/300]  Loss D: 1.3643,  Loss G: 0.7404
# Epoch [140/300]  Loss D: 1.4036,  Loss G: 0.7008
#   ✅ Checkpoint saved → /content/checkpoints/vanilla_gan/epoch_140.pt
#   🖼️  Image saved   → /content/images/vanilla_gan/epoch_140.png
# Epoch [141/300]  Loss D: 1.3781,  Loss G: 0.7336
# Epoch [142/300]  Loss D: 1.3732,  Loss G: 0.7237
# Epoch [143/300]  Loss D: 1.3869,  Loss G: 0.7278
# Epoch [144/300]  Loss D: 1.3814,  Loss G: 0.7293
# Epoch [145/300]  Loss D: 1.3570,  Loss G: 0.7102
# Epoch [146/300]  Loss D: 1.3733,  Loss G: 0.7004
# Epoch [147/300]  Loss D: 1.3713,  Loss G: 0.7268
# Epoch [148/300]  Loss D: 1.3543,  Loss G: 0.7441
# Epoch [149/300]  Loss D: 1.3998,  Loss G: 0.7054
# Epoch [150/300]  Loss D: 1.3677,  Loss G: 0.7124
# Epoch [151/300]  Loss D: 1.3813,  Loss G: 0.7178
# Epoch [152/300]  Loss D: 1.3782,  Loss G: 0.7359
# Epoch [153/300]  Loss D: 1.3907,  Loss G: 0.6868
# Epoch [154/300]  Loss D: 1.3638,  Loss G: 0.7261
# Epoch [155/300]  Loss D: 1.3663,  Loss G: 0.7170
# Epoch [156/300]  Loss D: 1.3838,  Loss G: 0.7204
# Epoch [157/300]  Loss D: 1.3564,  Loss G: 0.7145
# Epoch [158/300]  Loss D: 1.3849,  Loss G: 0.7364
# Epoch [159/300]  Loss D: 1.3807,  Loss G: 0.6935
# Epoch [160/300]  Loss D: 1.3987,  Loss G: 0.7107
#   ✅ Checkpoint saved → /content/checkpoints/vanilla_gan/epoch_160.pt
#   🖼️  Image saved   → /content/images/vanilla_gan/epoch_160.png
# Epoch [161/300]  Loss D: 1.3583,  Loss G: 0.7365
# Epoch [162/300]  Loss D: 1.3850,  Loss G: 0.6861
# Epoch [163/300]  Loss D: 1.3945,  Loss G: 0.6940
# Epoch [164/300]  Loss D: 1.3851,  Loss G: 0.7261
# Epoch [165/300]  Loss D: 1.4050,  Loss G: 0.7151
# Epoch [166/300]  Loss D: 1.3999,  Loss G: 0.7158
# Epoch [167/300]  Loss D: 1.4022,  Loss G: 0.7036
# Epoch [168/300]  Loss D: 1.3492,  Loss G: 0.7118
# Epoch [169/300]  Loss D: 1.3826,  Loss G: 0.7087
# Epoch [170/300]  Loss D: 1.3935,  Loss G: 0.7207
# Epoch [171/300]  Loss D: 1.3886,  Loss G: 0.6964
# Epoch [172/300]  Loss D: 1.3610,  Loss G: 0.7147
# Epoch [173/300]  Loss D: 1.3862,  Loss G: 0.7159
# Epoch [174/300]  Loss D: 1.3893,  Loss G: 0.7094
# Epoch [175/300]  Loss D: 1.3678,  Loss G: 0.7089
# Epoch [176/300]  Loss D: 1.3630,  Loss G: 0.7134
# Epoch [177/300]  Loss D: 1.3877,  Loss G: 0.7088
# Epoch [178/300]  Loss D: 1.3863,  Loss G: 0.7208
# Epoch [179/300]  Loss D: 1.3676,  Loss G: 0.7224
# Epoch [180/300]  Loss D: 1.3745,  Loss G: 0.7288
#   ✅ Checkpoint saved → /content/checkpoints/vanilla_gan/epoch_180.pt
#   🖼️  Image saved   → /content/images/vanilla_gan/epoch_180.png
# Epoch [181/300]  Loss D: 1.3731,  Loss G: 0.7100
# Epoch [182/300]  Loss D: 1.3729,  Loss G: 0.7072
# Epoch [183/300]  Loss D: 1.3684,  Loss G: 0.7120
# Epoch [184/300]  Loss D: 1.3951,  Loss G: 0.6950
# Epoch [185/300]  Loss D: 1.3780,  Loss G: 0.7156
# Epoch [186/300]  Loss D: 1.3601,  Loss G: 0.7159
# Epoch [187/300]  Loss D: 1.3834,  Loss G: 0.7224
# Epoch [188/300]  Loss D: 1.3434,  Loss G: 0.7139
# Epoch [189/300]  Loss D: 1.3704,  Loss G: 0.7167
# Epoch [190/300]  Loss D: 1.3832,  Loss G: 0.7123
# Epoch [191/300]  Loss D: 1.3758,  Loss G: 0.7215
# Epoch [192/300]  Loss D: 1.3604,  Loss G: 0.7166
# Epoch [193/300]  Loss D: 1.3947,  Loss G: 0.7177
# Epoch [194/300]  Loss D: 1.3452,  Loss G: 0.7277
# Epoch [195/300]  Loss D: 1.3707,  Loss G: 0.6979
# Epoch [196/300]  Loss D: 1.3913,  Loss G: 0.7153
# Epoch [197/300]  Loss D: 1.3681,  Loss G: 0.7389
# Epoch [198/300]  Loss D: 1.3993,  Loss G: 0.7243
# Epoch [199/300]  Loss D: 1.3467,  Loss G: 0.6906
# Epoch [200/300]  Loss D: 1.3417,  Loss G: 0.6934
#   ✅ Checkpoint saved → /content/checkpoints/vanilla_gan/epoch_200.pt
#   🖼️  Image saved   → /content/images/vanilla_gan/epoch_200.png
# Epoch [201/300]  Loss D: 1.3537,  Loss G: 0.7488
# Epoch [202/300]  Loss D: 1.4251,  Loss G: 0.7324
# Epoch [203/300]  Loss D: 1.3695,  Loss G: 0.7086
# Epoch [204/300]  Loss D: 1.3792,  Loss G: 0.7038
# Epoch [205/300]  Loss D: 1.3683,  Loss G: 0.7185
# Epoch [206/300]  Loss D: 1.3871,  Loss G: 0.7166
# Epoch [207/300]  Loss D: 1.3328,  Loss G: 0.7325
# Epoch [208/300]  Loss D: 1.3970,  Loss G: 0.7185
# Epoch [209/300]  Loss D: 1.3711,  Loss G: 0.7180
# Epoch [210/300]  Loss D: 1.3787,  Loss G: 0.7258
# Epoch [211/300]  Loss D: 1.3835,  Loss G: 0.7058
# Epoch [212/300]  Loss D: 1.3494,  Loss G: 0.7144
# Epoch [213/300]  Loss D: 1.3766,  Loss G: 0.7013
# Epoch [214/300]  Loss D: 1.3567,  Loss G: 0.6981
# Epoch [215/300]  Loss D: 1.3768,  Loss G: 0.7120
# Epoch [216/300]  Loss D: 1.3777,  Loss G: 0.6874
# Epoch [217/300]  Loss D: 1.3899,  Loss G: 0.7149
# Epoch [218/300]  Loss D: 1.3477,  Loss G: 0.7227
# Epoch [219/300]  Loss D: 1.3934,  Loss G: 0.7123
# Epoch [220/300]  Loss D: 1.3730,  Loss G: 0.6960
#   ✅ Checkpoint saved → /content/checkpoints/vanilla_gan/epoch_220.pt
#   🖼️  Image saved   → /content/images/vanilla_gan/epoch_220.png
# Epoch [221/300]  Loss D: 1.3995,  Loss G: 0.7423
# Epoch [222/300]  Loss D: 1.3925,  Loss G: 0.7131
# Epoch [223/300]  Loss D: 1.3494,  Loss G: 0.7162
# Epoch [224/300]  Loss D: 1.3702,  Loss G: 0.7049
# Epoch [225/300]  Loss D: 1.3754,  Loss G: 0.7358
# Epoch [226/300]  Loss D: 1.3664,  Loss G: 0.7467
# Epoch [227/300]  Loss D: 1.3534,  Loss G: 0.7229
# Epoch [228/300]  Loss D: 1.3924,  Loss G: 0.7255
# Epoch [229/300]  Loss D: 1.3526,  Loss G: 0.7029
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_474/3703009163.py in <cell line: 0>()
#      37
#      38         optimizer_G.zero_grad()
# ---> 39         loss_G.backward()
#      40         optimizer_G.step()
#      41
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     628                 inputs=inputs,
#     629             )
# --> 630         torch.autograd.backward(
#     631             self, gradient, retain_graph, create_graph, inputs=inputs
#     632         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     355
#     356     grad_tensors_ = _tensor_or_tensors_to_tuple(grad_tensors, len(tensors))
# --> 357     grad_tensors_ = _make_grads(tensors, grad_tensors_, is_grads_batched=False)
#     358     if retain_graph is None:
#     359         retain_graph = create_graph
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in _make_grads(outputs, grads, is_grads_batched)
#     228                         raise AssertionError("Expected output to be a torch.Tensor")
#     229                     new_grads.append(
# --> 230                         torch.ones_like(out, memory_format=torch.preserve_format)
#     231                     )
#     232             else:
#
# KeyboardInterrupt:

# %%
# ── Final visualisation ────────────────────────────────────────────────
G.eval()
with torch.no_grad():
    z = torch.randn(16, latent_dim, device=device)
    fake_images = G(z).view(-1, 1, 28, 28).cpu()

fig, axes = plt.subplots(4, 4, figsize=(6, 6))
for i, ax in enumerate(axes.flat):
    ax.imshow(fake_images[i][0], cmap='gray')
    ax.axis('off')
plt.suptitle("Vanilla GAN — Generated Images after 200 Epochs")
plt.tight_layout()
plt.savefig(os.path.join(image_dir, "final.png"), dpi=100, bbox_inches='tight')
plt.show()
print(f"All Vanilla GAN images saved in: {image_dir}")
# Out:
# All Vanilla GAN images saved in: /content/images/vanilla_gan

# %% [markdown]
# ---
# # 🟡 GAN Type 2 — Conditional GAN (cGAN)
# Extends the vanilla GAN with class label conditioning via embeddings, enabling controlled image generation.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

latent_dim  = 100
num_classes = 10
batch_size  = 128       # T4-friendly batch size
epochs      = 200
lr          = 0.0002
checkpoint_dir = "/content/checkpoints/cgan"
image_dir      = "/content/images/cgan"
os.makedirs(checkpoint_dir, exist_ok=True)
os.makedirs(image_dir, exist_ok=True)

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

dataset    = torchvision.datasets.FashionMNIST(root="./data", train=True, transform=transform, download=True)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=True)

# %%
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.label_emb = nn.Embedding(num_classes, num_classes)
        self.model = nn.Sequential(
            nn.Linear(latent_dim + num_classes, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, 784),
            nn.Tanh()
        )

    def forward(self, z, labels):
        c = self.label_emb(labels)
        x = torch.cat([z, c], dim=1)
        return self.model(x)


class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.label_emb = nn.Embedding(num_classes, num_classes)
        self.model = nn.Sequential(
            nn.Linear(784 + num_classes, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, img, labels):
        c = self.label_emb(labels)
        x = torch.cat([img, c], dim=1)
        return self.model(x)


G = Generator().to(device)
D = Discriminator().to(device)

criterion = nn.BCELoss()
opt_G = optim.Adam(G.parameters(), lr=lr, betas=(0.5, 0.999))
opt_D = optim.Adam(D.parameters(), lr=lr, betas=(0.5, 0.999))

# %%
class_names = ["T-shirt", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal",  "Shirt",   "Sneaker",  "Bag",   "Ankle boot"]

for epoch in range(1, epochs + 1):
    G.train()
    D.train()
    for real_imgs, labels in dataloader:

        real_imgs = real_imgs.view(-1, 784).to(device, non_blocking=True)
        labels    = labels.to(device, non_blocking=True)
        b         = real_imgs.size(0)

        real = torch.ones(b, 1, device=device)
        fake = torch.zeros(b, 1, device=device)

        # Train D
        out       = D(real_imgs, labels)
        loss_real = criterion(out, real)

        z         = torch.randn(b, latent_dim, device=device)
        fake_imgs = G(z, labels)
        out       = D(fake_imgs.detach(), labels)
        loss_fake = criterion(out, fake)

        loss_D = loss_real + loss_fake
        opt_D.zero_grad(); loss_D.backward(); opt_D.step()

        # Train G
        z         = torch.randn(b, latent_dim, device=device)
        fake_imgs = G(z, labels)
        out       = D(fake_imgs, labels)
        loss_G    = criterion(out, real)

        opt_G.zero_grad(); loss_G.backward(); opt_G.step()

    print(f"Epoch {epoch}/{epochs}  LossD={loss_D.item():.4f}  LossG={loss_G.item():.4f}")

    # ── Save checkpoint + images every 10 epochs ────────────────────────
    if epoch % 20 == 0:
        # Checkpoint
        ckpt_path = os.path.join(checkpoint_dir, f"epoch_{epoch:03d}.pt")
        torch.save({
            "epoch": epoch,
            "generator_state_dict": G.state_dict(),
            "discriminator_state_dict": D.state_dict(),
            "optimizer_G_state_dict": opt_G.state_dict(),
            "optimizer_D_state_dict": opt_D.state_dict(),
            "loss_G": loss_G.item(),
            "loss_D": loss_D.item(),
        }, ckpt_path)
        print(f"  ✅ Checkpoint saved → {ckpt_path}")

        # One sample per class
        G.eval()
        with torch.no_grad():
            z_fixed  = torch.randn(10, latent_dim, device=device)
            lbl_fixed = torch.arange(10, device=device)
            sample_imgs = G(z_fixed, lbl_fixed).view(-1, 1, 28, 28).cpu()
        G.train()

        fig, axes = plt.subplots(1, 10, figsize=(15, 2))
        for idx, ax in enumerate(axes):
            ax.imshow(sample_imgs[idx][0], cmap='gray')
            ax.set_title(class_names[idx], fontsize=7)
            ax.axis('off')
        plt.suptitle(f"cGAN — Epoch {epoch}")
        plt.tight_layout()
        img_path = os.path.join(image_dir, f"epoch_{epoch:03d}.png")
        plt.savefig(img_path, dpi=80, bbox_inches='tight')
        plt.close()
        print(f"  🖼️  Image saved   → {img_path}")
# Out:
# Epoch 1/200  LossD=0.1247  LossG=3.7737
# Epoch 2/200  LossD=0.8384  LossG=3.1108
# Epoch 3/200  LossD=0.3274  LossG=3.3877
# Epoch 4/200  LossD=0.4569  LossG=4.0021
# Epoch 5/200  LossD=0.6711  LossG=4.0186
# Epoch 6/200  LossD=0.7549  LossG=3.8662
# Epoch 7/200  LossD=0.9211  LossG=2.2294
# Epoch 8/200  LossD=0.8652  LossG=1.4345
# Epoch 9/200  LossD=1.5114  LossG=3.9671
# Epoch 10/200  LossD=0.9380  LossG=1.0461
# Epoch 11/200  LossD=0.9291  LossG=1.5404
# Epoch 12/200  LossD=1.0181  LossG=1.8223
# Epoch 13/200  LossD=0.8850  LossG=1.2718
# Epoch 14/200  LossD=1.0778  LossG=1.4499
# Epoch 15/200  LossD=1.1115  LossG=1.6524
# Epoch 16/200  LossD=0.9775  LossG=1.2483
# Epoch 17/200  LossD=1.1166  LossG=1.2070
# Epoch 18/200  LossD=1.2931  LossG=2.4508
# Epoch 19/200  LossD=1.1525  LossG=1.3091
# Epoch 20/200  LossD=1.2248  LossG=1.2911
#   ✅ Checkpoint saved → /content/checkpoints/cgan/epoch_020.pt
#   🖼️  Image saved   → /content/images/cgan/epoch_020.png
# Epoch 21/200  LossD=1.3990  LossG=0.6520
# Epoch 22/200  LossD=1.2481  LossG=1.4717
# Epoch 23/200  LossD=1.2428  LossG=1.4110
# Epoch 24/200  LossD=1.2605  LossG=0.7605
# Epoch 25/200  LossD=1.1756  LossG=1.1419
# Epoch 26/200  LossD=1.2929  LossG=1.0680
# Epoch 27/200  LossD=1.1466  LossG=1.2044
# Epoch 28/200  LossD=1.1106  LossG=1.2040
# Epoch 29/200  LossD=1.2999  LossG=0.7238
# Epoch 30/200  LossD=1.2004  LossG=1.0570
# Epoch 31/200  LossD=1.3762  LossG=0.6458
# Epoch 32/200  LossD=1.3162  LossG=0.5875
# Epoch 33/200  LossD=1.2451  LossG=1.0959
# Epoch 34/200  LossD=1.2665  LossG=1.0285
# Epoch 35/200  LossD=1.1982  LossG=1.0434
# Epoch 36/200  LossD=1.3217  LossG=1.0397
# Epoch 37/200  LossD=1.2290  LossG=0.9274
# Epoch 38/200  LossD=1.2507  LossG=0.8490
# Epoch 39/200  LossD=1.3045  LossG=0.9634
# Epoch 40/200  LossD=1.1855  LossG=0.8689
#   ✅ Checkpoint saved → /content/checkpoints/cgan/epoch_040.pt
#   🖼️  Image saved   → /content/images/cgan/epoch_040.png
# Epoch 41/200  LossD=1.2232  LossG=0.8675
# Epoch 42/200  LossD=1.1998  LossG=1.0144
# Epoch 43/200  LossD=1.2626  LossG=0.7830
# Epoch 44/200  LossD=1.1876  LossG=0.9623
# Epoch 45/200  LossD=1.2486  LossG=0.8914
# Epoch 46/200  LossD=1.2286  LossG=0.8432
# Epoch 47/200  LossD=1.2349  LossG=0.8666
# Epoch 48/200  LossD=1.2273  LossG=0.9156
# Epoch 49/200  LossD=1.2232  LossG=1.0937
# Epoch 50/200  LossD=1.2649  LossG=0.9149
# Epoch 51/200  LossD=1.2260  LossG=0.8172
# Epoch 52/200  LossD=1.2572  LossG=0.7374
# Epoch 53/200  LossD=1.1843  LossG=0.9359
# Epoch 54/200  LossD=1.2196  LossG=0.7891
# Epoch 55/200  LossD=1.2208  LossG=0.8863
# Epoch 56/200  LossD=1.2782  LossG=0.9804
# Epoch 57/200  LossD=1.3251  LossG=0.8455
# Epoch 58/200  LossD=1.2450  LossG=0.8073
# Epoch 59/200  LossD=1.2244  LossG=0.9423
# Epoch 60/200  LossD=1.2475  LossG=0.8862
#   ✅ Checkpoint saved → /content/checkpoints/cgan/epoch_060.pt
#   🖼️  Image saved   → /content/images/cgan/epoch_060.png
# Epoch 61/200  LossD=1.2207  LossG=1.0006
# Epoch 62/200  LossD=1.2555  LossG=0.8088
# Epoch 63/200  LossD=1.2884  LossG=0.8329
# Epoch 64/200  LossD=1.2264  LossG=0.9214
# Epoch 65/200  LossD=1.3576  LossG=0.8338
# Epoch 66/200  LossD=1.2671  LossG=0.8711
# Epoch 67/200  LossD=1.2121  LossG=0.9238
# Epoch 68/200  LossD=1.2807  LossG=0.8976
# Epoch 69/200  LossD=1.2372  LossG=0.9516
# Epoch 70/200  LossD=1.3036  LossG=0.8513
# Epoch 71/200  LossD=1.3359  LossG=0.7514
# Epoch 72/200  LossD=1.2596  LossG=0.9092
# Epoch 73/200  LossD=1.3129  LossG=0.9879
# Epoch 74/200  LossD=1.3053  LossG=0.8519
# Epoch 75/200  LossD=1.2767  LossG=0.9866
# Epoch 76/200  LossD=1.2571  LossG=0.8181
# Epoch 77/200  LossD=1.2532  LossG=0.8929
# Epoch 78/200  LossD=1.3115  LossG=0.8678
# Epoch 79/200  LossD=1.2840  LossG=0.9177
# Epoch 80/200  LossD=1.2862  LossG=0.7653
#   ✅ Checkpoint saved → /content/checkpoints/cgan/epoch_080.pt
#   🖼️  Image saved   → /content/images/cgan/epoch_080.png
# Epoch 81/200  LossD=1.3229  LossG=0.8108
# Epoch 82/200  LossD=1.3203  LossG=1.0062
# Epoch 83/200  LossD=1.3006  LossG=0.9327
# Epoch 84/200  LossD=1.2586  LossG=1.0158
# Epoch 85/200  LossD=1.2843  LossG=0.7815
# Epoch 86/200  LossD=1.2751  LossG=0.7285
# Epoch 87/200  LossD=1.2995  LossG=0.8034
# Epoch 88/200  LossD=1.3128  LossG=0.7768
# Epoch 89/200  LossD=1.2720  LossG=0.8915
# Epoch 90/200  LossD=1.3056  LossG=0.8835
# Epoch 91/200  LossD=1.2348  LossG=0.7865
# Epoch 92/200  LossD=1.2421  LossG=0.8599
# Epoch 93/200  LossD=1.3186  LossG=0.7164
# Epoch 94/200  LossD=1.3374  LossG=1.0241
# Epoch 95/200  LossD=1.1284  LossG=0.9129
# Epoch 96/200  LossD=1.3153  LossG=0.7665
# Epoch 97/200  LossD=1.2694  LossG=0.8801
# Epoch 98/200  LossD=1.2071  LossG=0.8610
# Epoch 99/200  LossD=1.2392  LossG=1.0105
# Epoch 100/200  LossD=1.1797  LossG=1.0643
#   ✅ Checkpoint saved → /content/checkpoints/cgan/epoch_100.pt
#   🖼️  Image saved   → /content/images/cgan/epoch_100.png
# Epoch 101/200  LossD=1.2869  LossG=0.9120
# Epoch 102/200  LossD=1.2817  LossG=0.8346
# Epoch 103/200  LossD=1.2240  LossG=1.0973
# Epoch 104/200  LossD=1.2121  LossG=0.9828
# Epoch 105/200  LossD=1.3019  LossG=0.7973
# Epoch 106/200  LossD=1.2563  LossG=0.9318
# Epoch 107/200  LossD=1.2331  LossG=0.8696
# Epoch 108/200  LossD=1.2267  LossG=0.8170
# Epoch 109/200  LossD=1.2773  LossG=0.9994
# Epoch 110/200  LossD=1.2968  LossG=0.8655
# Epoch 111/200  LossD=1.2751  LossG=0.8073
# Epoch 112/200  LossD=1.3041  LossG=1.0415
# Epoch 113/200  LossD=1.1903  LossG=0.8477
# Epoch 114/200  LossD=1.2670  LossG=0.9619
# Epoch 115/200  LossD=1.3831  LossG=0.9018
# Epoch 116/200  LossD=1.2162  LossG=0.8147
# Epoch 117/200  LossD=1.1502  LossG=1.0167
# Epoch 118/200  LossD=1.2288  LossG=0.8547
# Epoch 119/200  LossD=1.2480  LossG=0.9646
# Epoch 120/200  LossD=1.2412  LossG=1.0547
#   ✅ Checkpoint saved → /content/checkpoints/cgan/epoch_120.pt
#   🖼️  Image saved   → /content/images/cgan/epoch_120.png
# Epoch 121/200  LossD=1.1930  LossG=0.8569
# Epoch 122/200  LossD=1.2525  LossG=0.9607
# Epoch 123/200  LossD=1.2272  LossG=0.8886
# Epoch 124/200  LossD=1.2445  LossG=0.8774
# Epoch 125/200  LossD=1.1872  LossG=0.9567
# Epoch 126/200  LossD=1.1947  LossG=0.7707
# Epoch 127/200  LossD=1.2043  LossG=0.9567
# Epoch 128/200  LossD=1.2079  LossG=0.8149
# Epoch 129/200  LossD=1.1646  LossG=0.9263
# Epoch 130/200  LossD=1.2528  LossG=1.1189
# Epoch 131/200  LossD=1.2213  LossG=0.8137
# Epoch 132/200  LossD=1.2603  LossG=0.7374
# Epoch 133/200  LossD=1.2477  LossG=0.7301
# Epoch 134/200  LossD=1.1859  LossG=1.0058
# Epoch 135/200  LossD=1.2053  LossG=0.9650
# Epoch 136/200  LossD=1.2223  LossG=0.9609
# Epoch 137/200  LossD=1.2687  LossG=0.9831
# Epoch 138/200  LossD=1.2620  LossG=0.9935
# Epoch 139/200  LossD=1.3009  LossG=0.8383
# Epoch 140/200  LossD=1.1727  LossG=0.8726
#   ✅ Checkpoint saved → /content/checkpoints/cgan/epoch_140.pt
#   🖼️  Image saved   → /content/images/cgan/epoch_140.png
# Epoch 141/200  LossD=1.2629  LossG=0.8923
# Epoch 142/200  LossD=1.3089  LossG=0.7231
# Epoch 143/200  LossD=1.1745  LossG=1.0283
# Epoch 144/200  LossD=1.2340  LossG=0.8318
# Epoch 145/200  LossD=1.1860  LossG=1.0462
# Epoch 146/200  LossD=1.2597  LossG=1.0545
# Epoch 147/200  LossD=1.2127  LossG=0.9620
# Epoch 148/200  LossD=1.2430  LossG=0.8784
# Epoch 149/200  LossD=1.2589  LossG=0.8840
# Epoch 150/200  LossD=1.2651  LossG=0.8415
# Epoch 151/200  LossD=1.2414  LossG=0.8982
# Epoch 152/200  LossD=1.1808  LossG=0.7810
# Epoch 153/200  LossD=1.2575  LossG=0.8537
# Epoch 154/200  LossD=1.2283  LossG=1.0509
# Epoch 155/200  LossD=1.1649  LossG=0.8509
# Epoch 156/200  LossD=1.3337  LossG=0.7560
# Epoch 157/200  LossD=1.3051  LossG=0.6772
# Epoch 158/200  LossD=1.1887  LossG=0.8678
# Epoch 159/200  LossD=1.1934  LossG=1.1916
# Epoch 160/200  LossD=1.2810  LossG=0.9076
#   ✅ Checkpoint saved → /content/checkpoints/cgan/epoch_160.pt
#   🖼️  Image saved   → /content/images/cgan/epoch_160.png
# Epoch 161/200  LossD=1.2564  LossG=1.0253
# Epoch 162/200  LossD=1.2327  LossG=0.9045
# Epoch 163/200  LossD=1.1738  LossG=0.9198
# Epoch 164/200  LossD=1.2274  LossG=1.0844
# Epoch 165/200  LossD=1.2259  LossG=0.9284
# Epoch 166/200  LossD=1.2058  LossG=0.8833
# Epoch 167/200  LossD=1.1258  LossG=1.1068
# Epoch 168/200  LossD=1.3218  LossG=0.8718
# Epoch 169/200  LossD=1.2181  LossG=0.9314
# Epoch 170/200  LossD=1.2558  LossG=0.9265
# Epoch 171/200  LossD=1.3397  LossG=0.9891
# Epoch 172/200  LossD=1.2176  LossG=0.8951
# Epoch 173/200  LossD=1.2220  LossG=1.0581
# Epoch 174/200  LossD=1.2257  LossG=1.0486
# Epoch 175/200  LossD=1.2463  LossG=0.9162
# Epoch 176/200  LossD=1.2552  LossG=0.9586
# Epoch 177/200  LossD=1.2052  LossG=0.9047
# Epoch 178/200  LossD=1.2527  LossG=0.8702
# Epoch 179/200  LossD=1.0975  LossG=0.9145
# Epoch 180/200  LossD=1.1997  LossG=0.9715
#   ✅ Checkpoint saved → /content/checkpoints/cgan/epoch_180.pt
#   🖼️  Image saved   → /content/images/cgan/epoch_180.png
# Epoch 181/200  LossD=1.2117  LossG=0.9522
# Epoch 182/200  LossD=1.2362  LossG=0.9067
# Epoch 183/200  LossD=1.2051  LossG=0.8943
# Epoch 184/200  LossD=1.1320  LossG=0.9729
# Epoch 185/200  LossD=1.1456  LossG=1.0317
# Epoch 186/200  LossD=1.2449  LossG=1.0048
# Epoch 187/200  LossD=1.1807  LossG=1.1192
# Epoch 188/200  LossD=1.3088  LossG=1.0780
# Epoch 189/200  LossD=1.2933  LossG=0.8202
# Epoch 190/200  LossD=1.2894  LossG=1.0399
# Epoch 191/200  LossD=1.2597  LossG=0.9227
# Epoch 192/200  LossD=1.1897  LossG=1.1055
# Epoch 193/200  LossD=1.2575  LossG=0.9249
# Epoch 194/200  LossD=1.1038  LossG=1.0133
# Epoch 195/200  LossD=1.1952  LossG=1.0296
# Epoch 196/200  LossD=1.0763  LossG=1.0467
# Epoch 197/200  LossD=1.2779  LossG=1.1011
# Epoch 198/200  LossD=1.1814  LossG=0.9036
# Epoch 199/200  LossD=1.2275  LossG=0.9687
# Epoch 200/200  LossD=1.1032  LossG=1.1409
#   ✅ Checkpoint saved → /content/checkpoints/cgan/epoch_200.pt
#   🖼️  Image saved   → /content/images/cgan/epoch_200.png

# %%
# ── Final visualisation ────────────────────────────────────────────────
G.eval()
with torch.no_grad():
    z      = torch.randn(10, latent_dim, device=device)
    labels = torch.arange(10, device=device)
    imgs   = G(z, labels).view(-1, 1, 28, 28).cpu()

fig, axes = plt.subplots(1, 10, figsize=(15, 2))
for i, ax in enumerate(axes):
    ax.imshow(imgs[i][0], cmap='gray')
    ax.set_title(class_names[i], fontsize=7)
    ax.axis('off')
plt.suptitle("cGAN — One sample per class after 200 Epochs")
plt.tight_layout()
plt.savefig(os.path.join(image_dir, "final.png"), dpi=100, bbox_inches='tight')
plt.show()
print(f"All cGAN images saved in: {image_dir}")
# Out:
# All cGAN images saved in: /content/images/cgan

# %% [markdown]
# ---
# # 🟢 GAN Type 3 — DCGAN (Deep Convolutional GAN)
# Uses convolutional and transposed convolutional layers. Works directly on 2D image tensors with BatchNorm for stability.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

latent_dim = 100
batch_size = 128        # T4-friendly batch size
epochs     = 200
lr         = 0.0002
checkpoint_dir = "/content/checkpoints/dcgan"
image_dir      = "/content/images/dcgan"
os.makedirs(checkpoint_dir, exist_ok=True)
os.makedirs(image_dir, exist_ok=True)

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

dataset    = torchvision.datasets.FashionMNIST(root="./data", train=True, transform=transform, download=True)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=True)

# %%
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, 256, 7, 1, 0, bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(True),

            nn.ConvTranspose2d(256, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(True),

            nn.ConvTranspose2d(128, 1, 4, 2, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, z):
        z = z.unsqueeze(2).unsqueeze(3)
        return self.model(z)


class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Conv2d(1, 128, 4, 2, 1),
            nn.LeakyReLU(0.2),

            nn.Conv2d(128, 256, 4, 2, 1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),

            nn.Flatten(),
            nn.Linear(256 * 7 * 7, 1),
            nn.Sigmoid()
        )

    def forward(self, img):
        return self.model(img)


G = Generator().to(device)
D = Discriminator().to(device)

criterion = nn.BCELoss()
opt_G = optim.Adam(G.parameters(), lr=lr, betas=(0.5, 0.999))
opt_D = optim.Adam(D.parameters(), lr=lr, betas=(0.5, 0.999))

# %%
for epoch in range(1, epochs + 1):
    G.train()
    D.train()
    for real_imgs, _ in dataloader:

        real_imgs = real_imgs.to(device, non_blocking=True)
        b = real_imgs.size(0)

        real = torch.ones(b, 1, device=device)
        fake = torch.zeros(b, 1, device=device)

        # Train D
        out       = D(real_imgs)
        loss_real = criterion(out, real)

        z         = torch.randn(b, latent_dim, device=device)
        fake_imgs = G(z)
        out       = D(fake_imgs.detach())
        loss_fake = criterion(out, fake)

        loss_D = loss_real + loss_fake
        opt_D.zero_grad(); loss_D.backward(); opt_D.step()

        # Train G
        z         = torch.randn(b, latent_dim, device=device)
        fake_imgs = G(z)
        out       = D(fake_imgs)
        loss_G    = criterion(out, real)

        opt_G.zero_grad(); loss_G.backward(); opt_G.step()

    print(f"Epoch {epoch}/{epochs}  LossD={loss_D.item():.4f}  LossG={loss_G.item():.4f}")

    # ── Save checkpoint + images every 10 epochs ────────────────────────
    if epoch % 20 == 0:
        # Checkpoint
        ckpt_path = os.path.join(checkpoint_dir, f"epoch_{epoch:03d}.pt")
        torch.save({
            "epoch": epoch,
            "generator_state_dict": G.state_dict(),
            "discriminator_state_dict": D.state_dict(),
            "optimizer_G_state_dict": opt_G.state_dict(),
            "optimizer_D_state_dict": opt_D.state_dict(),
            "loss_G": loss_G.item(),
            "loss_D": loss_D.item(),
        }, ckpt_path)
        print(f"  ✅ Checkpoint saved → {ckpt_path}")

        # Generated image grid
        G.eval()
        with torch.no_grad():
            z_fixed     = torch.randn(16, latent_dim, device=device)
            sample_imgs = G(z_fixed).cpu()
        G.train()

        fig, axes = plt.subplots(4, 4, figsize=(6, 6))
        for idx, ax in enumerate(axes.flat):
            ax.imshow(sample_imgs[idx][0], cmap='gray')
            ax.axis('off')
        plt.suptitle(f"DCGAN — Epoch {epoch}")
        plt.tight_layout()
        img_path = os.path.join(image_dir, f"epoch_{epoch:03d}.png")
        plt.savefig(img_path, dpi=80, bbox_inches='tight')
        plt.close()
        print(f"  🖼️  Image saved   → {img_path}")
# Out:
# Epoch 1/200  LossD=0.7464  LossG=2.1178
# Epoch 2/200  LossD=0.9067  LossG=0.7869
# Epoch 3/200  LossD=1.0637  LossG=0.7542
# Epoch 4/200  LossD=0.8005  LossG=1.1993
# Epoch 5/200  LossD=1.2075  LossG=1.8684
# Epoch 6/200  LossD=0.5214  LossG=1.1127
# Epoch 7/200  LossD=0.6635  LossG=1.9494
# Epoch 8/200  LossD=0.7678  LossG=1.6467
# Epoch 9/200  LossD=0.7974  LossG=1.6727
# Epoch 10/200  LossD=0.5185  LossG=1.4093
# Epoch 11/200  LossD=0.8451  LossG=1.2150
# Epoch 12/200  LossD=0.6821  LossG=1.3445
# Epoch 13/200  LossD=0.6895  LossG=1.2153
# Epoch 14/200  LossD=0.7484  LossG=2.2774
# Epoch 15/200  LossD=0.7754  LossG=1.3649
# Epoch 16/200  LossD=0.5750  LossG=2.1310
# Epoch 17/200  LossD=0.7313  LossG=1.2728
# Epoch 18/200  LossD=0.6683  LossG=1.0447
# Epoch 19/200  LossD=1.1003  LossG=3.1630
# Epoch 20/200  LossD=1.0105  LossG=3.2351
#   ✅ Checkpoint saved → /content/checkpoints/dcgan/epoch_020.pt
#   🖼️  Image saved   → /content/images/dcgan/epoch_020.png
# Epoch 21/200  LossD=0.8750  LossG=1.6778
# Epoch 22/200  LossD=1.0806  LossG=1.6280
# Epoch 23/200  LossD=0.4710  LossG=2.1145
# Epoch 24/200  LossD=0.5843  LossG=3.3857
# Epoch 25/200  LossD=0.4515  LossG=1.8523
# Epoch 26/200  LossD=0.5886  LossG=2.5905
# Epoch 27/200  LossD=0.5510  LossG=2.2980
# Epoch 28/200  LossD=0.4775  LossG=2.2818
# Epoch 29/200  LossD=0.6214  LossG=1.9160
# Epoch 30/200  LossD=0.7669  LossG=3.8260
# Epoch 31/200  LossD=0.6009  LossG=2.2733
# Epoch 32/200  LossD=0.3629  LossG=1.8986
# Epoch 33/200  LossD=0.2842  LossG=3.2541
# Epoch 34/200  LossD=0.5910  LossG=2.9855
# Epoch 35/200  LossD=0.5174  LossG=2.3236
# Epoch 36/200  LossD=0.4455  LossG=2.4026
# Epoch 37/200  LossD=0.7705  LossG=2.7588
# Epoch 38/200  LossD=0.4393  LossG=1.8673
# Epoch 39/200  LossD=0.3140  LossG=1.9194
# Epoch 40/200  LossD=0.3189  LossG=2.2269
#   ✅ Checkpoint saved → /content/checkpoints/dcgan/epoch_040.pt
#   🖼️  Image saved   → /content/images/dcgan/epoch_040.png
# Epoch 41/200  LossD=0.3298  LossG=3.3208
# Epoch 42/200  LossD=0.5778  LossG=3.7650
# Epoch 43/200  LossD=0.3949  LossG=2.2811
# Epoch 44/200  LossD=0.5595  LossG=1.9744
# Epoch 45/200  LossD=0.6500  LossG=5.1774
# Epoch 46/200  LossD=0.7746  LossG=4.1086
# Epoch 47/200  LossD=0.3765  LossG=2.9915
# Epoch 48/200  LossD=0.6776  LossG=1.4426
# Epoch 49/200  LossD=0.3535  LossG=2.7509
# Epoch 50/200  LossD=0.3751  LossG=4.0281
# Epoch 51/200  LossD=0.6192  LossG=3.3975
# Epoch 52/200  LossD=0.2396  LossG=3.3620
# Epoch 53/200  LossD=0.8999  LossG=1.3805
# Epoch 54/200  LossD=0.3206  LossG=2.7333
# Epoch 55/200  LossD=0.4226  LossG=1.9648
# Epoch 56/200  LossD=1.1223  LossG=1.3539
# Epoch 57/200  LossD=0.7736  LossG=4.0995
# Epoch 58/200  LossD=0.2667  LossG=2.6396
# Epoch 59/200  LossD=0.3829  LossG=2.6356
# Epoch 60/200  LossD=0.3730  LossG=4.2656
#   ✅ Checkpoint saved → /content/checkpoints/dcgan/epoch_060.pt
#   🖼️  Image saved   → /content/images/dcgan/epoch_060.png
# Epoch 61/200  LossD=0.3044  LossG=3.5952
# Epoch 62/200  LossD=0.2448  LossG=2.0515
# Epoch 63/200  LossD=0.3657  LossG=2.9678
# Epoch 64/200  LossD=0.6033  LossG=3.5494
# Epoch 65/200  LossD=0.1650  LossG=3.2627
# Epoch 66/200  LossD=0.3285  LossG=1.7303
# Epoch 67/200  LossD=0.3168  LossG=3.4336
# Epoch 68/200  LossD=0.2414  LossG=3.3184
# Epoch 69/200  LossD=0.4212  LossG=3.9566
# Epoch 70/200  LossD=0.2900  LossG=3.4640
# Epoch 71/200  LossD=0.2778  LossG=3.5158
# Epoch 72/200  LossD=0.1427  LossG=4.3083
# Epoch 73/200  LossD=0.3860  LossG=3.8382
# Epoch 74/200  LossD=0.5626  LossG=4.0744
# Epoch 75/200  LossD=0.2304  LossG=4.1543
# Epoch 76/200  LossD=0.7111  LossG=5.4046
# Epoch 77/200  LossD=0.2909  LossG=3.2931
# Epoch 78/200  LossD=0.1990  LossG=2.6880
# Epoch 79/200  LossD=0.4957  LossG=3.2071
# Epoch 80/200  LossD=0.1942  LossG=4.1949
#   ✅ Checkpoint saved → /content/checkpoints/dcgan/epoch_080.pt
#   🖼️  Image saved   → /content/images/dcgan/epoch_080.png
# Epoch 81/200  LossD=0.3348  LossG=3.8329
# Epoch 82/200  LossD=0.2918  LossG=3.9506
# Epoch 83/200  LossD=0.1630  LossG=3.2891
# Epoch 84/200  LossD=0.2792  LossG=3.7016
# Epoch 85/200  LossD=1.5880  LossG=7.4326
# Epoch 86/200  LossD=0.2580  LossG=3.1525
# Epoch 87/200  LossD=0.2364  LossG=3.5906
# Epoch 88/200  LossD=0.2075  LossG=3.8925
# Epoch 89/200  LossD=0.2570  LossG=4.3030
# Epoch 90/200  LossD=0.2481  LossG=2.6627
# Epoch 91/200  LossD=0.2932  LossG=3.3885
# Epoch 92/200  LossD=0.2755  LossG=3.6879
# Epoch 93/200  LossD=0.2274  LossG=2.9798
# Epoch 94/200  LossD=0.3266  LossG=4.4867
# Epoch 95/200  LossD=0.2729  LossG=3.3753
# Epoch 96/200  LossD=0.0965  LossG=3.2569
# Epoch 97/200  LossD=0.3047  LossG=2.0409
# Epoch 98/200  LossD=0.5715  LossG=4.1130
# Epoch 99/200  LossD=0.1179  LossG=4.3677
# Epoch 100/200  LossD=0.2423  LossG=3.7387
#   ✅ Checkpoint saved → /content/checkpoints/dcgan/epoch_100.pt
#   🖼️  Image saved   → /content/images/dcgan/epoch_100.png
# Epoch 101/200  LossD=1.6304  LossG=0.5883
# Epoch 102/200  LossD=0.0943  LossG=4.6538
# Epoch 103/200  LossD=0.1079  LossG=3.4392
# Epoch 104/200  LossD=0.2025  LossG=3.8002
# Epoch 105/200  LossD=0.3009  LossG=4.7088
# Epoch 106/200  LossD=0.1840  LossG=3.6279
# Epoch 107/200  LossD=0.2426  LossG=2.1862
# Epoch 108/200  LossD=0.4300  LossG=2.6829
# Epoch 109/200  LossD=0.2401  LossG=3.4120
# Epoch 110/200  LossD=0.2647  LossG=4.1980
# Epoch 111/200  LossD=0.2198  LossG=3.7744
# Epoch 112/200  LossD=0.1425  LossG=3.9785
# Epoch 113/200  LossD=0.2694  LossG=3.3326
# Epoch 114/200  LossD=0.1453  LossG=3.7829
# Epoch 115/200  LossD=0.1992  LossG=4.0478

# %%
# ── Final visualisation ────────────────────────────────────────────────
G.eval()
with torch.no_grad():
    z         = torch.randn(16, latent_dim, device=device)
    fake_imgs = G(z).cpu()

fig, axes = plt.subplots(4, 4, figsize=(6, 6))
for i, ax in enumerate(axes.flat):
    ax.imshow(fake_imgs[i][0], cmap='gray')
    ax.axis('off')
plt.suptitle("DCGAN — Generated Images after 200 Epochs")
plt.tight_layout()
plt.savefig(os.path.join(image_dir, "final.png"), dpi=100, bbox_inches='tight')
plt.show()
print(f"All DCGAN images saved in: {image_dir}")
